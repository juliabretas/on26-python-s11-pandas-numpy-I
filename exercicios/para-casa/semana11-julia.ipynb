# %% [markdown]
# **Introdução**
# - A base de dados escolhida nos traz informações sobre os primeiros desenhos que representaram personagens LBGTQIA+ e pessoas com identidade de gênero, fora da cis normalidade. A base possui dados sobre os canais, as plataformas, a forma como esses personagens foram mostrados, além de informações sobre raça e deficiências.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("lgbtqia-characters-in-youth-cartoons.csv")
df
# Out:
#           character                                show        gender  \
# 0        Acid Storm            Transformers: Cyberverse   Genderfluid
# 1              Adam                          The Hollow      Cis, Man
# 2              Adam         Voltron: Legendary Defender      Cis, Man
# 3             Adora  She-Ra and the Princesses of Power    Cis, Woman
# 4         Alexander                     Big City Greens      Cis, Man
# ..              ...                                 ...           ...
# 254           Zadie                       Danger & Eggs  Trans, Woman
# 255  Zarya Moonwolf                           Mysticons    Cis, Woman
# 256            Zerk                       Ready Jet Go!       Unknown
# 257            Zoit                      Lloyd in Space       Agender
# 258        Zucchini                       Ready Jet Go!       Unknown
#
#              race                 role  \
# 0             NaN  Recurring Character
# 1             POC       Main Character
# ...

# %%
df.shape
# Out:
# (259, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259 entries, 0 to 258
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   character       259 non-null    object
#  1   show            259 non-null    object
#  2   gender          259 non-null    object
#  3   race            152 non-null    object
#  4   role            259 non-null    object
#  5   studio          259 non-null    object
#  6   representation  259 non-null    object
#  7   orientation     259 non-null    object
#  8   year            259 non-null    int64
#  9   platform        259 non-null    object
#  10  confirmation    259 non-null    object
#  11  disability      23 non-null     object
#  12  rating          187 non-null    object
# dtypes: int64(1), object(12)
# memory usage: 26.4+ KB

# %%
df.head(3)
# Out:
#     character                         show       gender     race  \
# 0  Acid Storm     Transformers: Cyberverse  Genderfluid      NaN
# 1        Adam                   The Hollow     Cis, Man      POC
# 2        Adam  Voltron: Legendary Defender     Cis, Man  Unknown
#
#                   role                                             studio  \
# 0  Recurring Character          Allspark Animation, Boulder Media Limited
# 1       Main Character                                Slap Happy Cartoons
# 2      Guest Character  DreamWorks Animation Television, World Events ...
#
#   representation orientation  year         platform  \
# 0       Implicit     Unknown  2018  Cartoon Network
# 1       Explicit         Gay  2020          Netflix
# 2       Explicit         Gay  2018          Netflix
#
#                                     confirmation      disability rating
# 0              Social Media, Gender Presentation             NaN    NaN
# ...

# %%
df.columns
# Out:
# Index(['character', 'show', 'gender', 'race', 'role', 'studio',
#        'representation', 'orientation', 'year', 'disability'],
#       dtype='object')

# %%
df = df.dropna()
df.shape
# Out:
# (9, 10)

# %%
df = df.drop(['platform', 'rating', 'confirmation'], axis=1)
df.shape
# Out:
# (187, 10)

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (9, 10)

# %%
df.reset_index()
# Out:
#    index        character                             show        gender  \
# 0     46      D.D. Danger                    Danger & Eggs          Masc
# 1     47    Dana Dufresne                   The Loud House  Trans, Woman
# 2     54        Dr. Kevin  The Boss Baby: Back in Business      Cis, Man
# 3     82          Houston                        Braceface      Cis, Man
# 4    119            Layla                    Danger & Eggs    Cis, Woman
# 5    137  Mark Dion Jones                        Braceface      Cis, Man
# 6    184     Richie Foley                     Static Shock      Cis, Man
# 7    226            Terry                  Big City Greens      Cis, Man
# 8    248             Wren             Middle School Moguls     Nonbinary
#
#            race                 role  \
# 0         White       Main Character
# 1         White  Recurring Character
# 2           POC      Guest Character
# 3           POC      Guest Character
# 4           POC      Guest Character
# ...

# %%
df_sorted = df.sort_values(by='year')
df_sorted
# Out:
#            character                             show        gender  \
# 82           Houston                        Braceface      Cis, Man
# 137  Mark Dion Jones                        Braceface      Cis, Man
# 184     Richie Foley                     Static Shock      Cis, Man
# 46       D.D. Danger                    Danger & Eggs          Masc
# 226            Terry                  Big City Greens      Cis, Man
# 47     Dana Dufresne                   The Loud House  Trans, Woman
# 248             Wren             Middle School Moguls     Nonbinary
# 54         Dr. Kevin  The Boss Baby: Back in Business      Cis, Man
# 119            Layla                    Danger & Eggs    Cis, Woman
#
#              race                 role  \
# 82            POC      Guest Character
# 137         White  Recurring Character
# 184         White       Main Character
# 46          White       Main Character
# 226  Undetermined  Recurring Character
# 47          White  Recurring Character
# ...

# %%
traducoes = {
    'character' : 'Personagem',
    'show': 'Desenho',
    'gender': 'Gênero',
    'race': 'Raça',
    'role': 'Papel',
    'studio': 'Estudio',
    'representation': 'Representação',
    'orientation': 'Orientação',
    'year': 'Ano',
    'platform': 'Plataforma',
    'confirmation': 'Confirmação',
    'disability': 'Deficiência',
    'rating': 'Avaliação'
}

novas_colunas = []

for chave, valor in traducoes.items():
    novas_colunas.append(valor)

novas_colunas
# Out:
# ['Personagem',
#  'Desenho',
#  'Gênero',
#  'Raça',
#  'Papel',
#  'Estudio',
#  'Representação',
#  'Orientação',
#  'Ano',
#  'Plataforma',
#  'Confirmação',
#  'Deficiência',
#  'Avaliação']

# %%
df_copia = df.copy()

# %% [markdown]
# **INSIGHTS**
# - Pessoas que se identificam fora do espectro de normalidade cis ainda são pouco representadas em desenhos.
# - Personagens negras são mais comumentes colocadas em papéis secundários do que as personagens brancas
